# %% [markdown]
# # Introduction
# This comprehensive financial dataset combines transaction records, customer information, and card data from a banking institution, spanning the 2010s decade. The dataset is designed for multiple analytical purposes, including synthetic fraud detection, customer behavior analysis, and expense forecasting.
#
# Dataset Components
# 1. Transaction Data (transactions_data.csv)
# Detailed transaction records including amounts, timestamps, and merchant details
# Covers transactions throughout the 2010s
# Features transaction types, amounts, and merchant information
# Perfect for analyzing spending patterns and building fraud detection models
# 2. Card Information (cards_dat.csv)
# Credit and debit card details
# Includes card limits, types, and activation dates
# Links to customer accounts via card_id
# Essential for understanding customer financial profiles
# 3. Merchant Category Codes (mcc_codes.json)
# Standard classification codes for business types
# Enables transaction categorization and spending analysis
# Industry-standard MCC codes with descriptions
# 4. Fraud Labels (train_fraud_labels.json)
# Binary classification labels for transactions
# Indicates fraudulent vs. legitimate transactions
# Ideal for training supervised fraud detection models
# 5. User Data (users_data)
# Demographic information about customers
# Account-related details
# Enables customer segmentation and personalized analysis

# %%
import numpy as np
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import warnings
warnings.filterwarnings('ignore')
# Out:
# /kaggle/input/transactions-fraud-datasets/mcc_codes.json
# /kaggle/input/transactions-fraud-datasets/users_data.csv
# /kaggle/input/transactions-fraud-datasets/transactions_data.csv
# /kaggle/input/transactions-fraud-datasets/cards_data.csv
# /kaggle/input/transactions-fraud-datasets/train_fraud_labels.json

# %% [markdown]
# # Transactions Data Analysis

# %%
import os
import warnings
import numpy as np
import pandas as pd

# Set local directory path
folder_path = r"C:\Users\DELL\Desktop\Skills\Financial Analysis"

# List all files in your local project folder
for dirname, _, filenames in os.walk(folder_path):
    for filename in filenames:
        print(os.path.join(dirname, filename))

warnings.filterwarnings('ignore') 

# Load transactions data
df = pd.read_csv(os.path.join(folder_path, "transactions_data.csv"))
df
# Out:
# C:\Users\DELL\Desktop\Skills\Financial Analysis\cards_data.csv
# C:\Users\DELL\Desktop\Skills\Financial Analysis\data-cleaning-processing-merging.ipynb
# C:\Users\DELL\Desktop\Skills\Financial Analysis\financial-transactions-analysis.ipynb
# C:\Users\DELL\Desktop\Skills\Financial Analysis\mcc_codes.json
# C:\Users\DELL\Desktop\Skills\Financial Analysis\New Text Document.txt
# C:\Users\DELL\Desktop\Skills\Financial Analysis\train_fraud_labels.json
# C:\Users\DELL\Desktop\Skills\Financial Analysis\transaction-analysis-and-prediction.ipynb
# C:\Users\DELL\Desktop\Skills\Financial Analysis\transactions-dataset-eda.ipynb
# C:\Users\DELL\Desktop\Skills\Financial Analysis\transactions_data.csv
# C:\Users\DELL\Desktop\Skills\Financial Analysis\users_data.csv
# C:\Users\DELL\Desktop\Skills\Financial Analysis\.ipynb_checkpoints\data-cleaning-processing-merging-checkpoint.ipynb
# C:\Users\DELL\Desktop\Skills\Financial Analysis\.ipynb_checkpoints\transactions-dataset-eda-checkpoint.ipynb
#                 id                 date  client_id  card_id   amount  \
# 0          7475327  2010-01-01 00:01:00       1556     2972  $-77.00
# 1          7475328  2010-01-01 00:02:00        561     4575   $14.57
# 2          7475329  2010-01-01 00:02:00       1129      102   $80.00
# 3          7475331  2010-01-01 00:05:00        430     2860  $200.00
# 4          7475332  2010-01-01 00:06:00        848     3915   $46.41
# ...            ...                  ...        ...      ...      ...
# 13305910  23761868  2019-10-31 23:56:00       1718     2379    $1.11
# 13305911  23761869  2019-10-31 23:56:00       1766     2066   $12.80
# 13305912  23761870  2019-10-31 23:57:00        199     1031   $40.44
# 13305913  23761873  2019-10-31 23:58:00       1986     5443    $4.00
# 13305914  23761874  2019-10-31 23:59:00        489     5697   $12.88
#
#                     use_chip  merchant_id merchant_city merchant_state  \
# 0          Swipe Transaction        59935        Beulah             ND
# 1          Swipe Transaction        67570    Bettendorf             IA
# 2          Swipe Transaction        27092         Vista             CA
# 3          Swipe Transaction        27092   Crown Point             IN
# 4          Swipe Transaction        13051       Harwood             MD
# ...                      ...          ...           ...            ...
# 13305910    Chip Transaction        86438   West Covina             CA
# 13305911  Online Transaction        39261        ONLINE            NaN
# 13305912   Swipe Transaction         2925         Allen             TX
# 13305913    Chip Transaction        46284     Daly City             CA
# 13305914    Chip Transaction        24658    Greenbrier             TN
#
#               zip   mcc errors
# 0         58523.0  5499    NaN
# 1         52722.0  5311    NaN
# 2         92084.0  4829    NaN
# 3         46307.0  4829    NaN
# 4         20776.0  5813    NaN
# ...           ...   ...    ...
# 13305910  91792.0  5499    NaN
# 13305911      NaN  5815    NaN
# 13305912  75002.0  4900    NaN
# 13305913  94014.0  5411    NaN
# 13305914  37073.0  5921    NaN
#
# [13305915 rows x 12 columns]

# %%
import json
import pandas as pd

json_path = r"C:\Users\DELL\Desktop\Skills\Financial Analysis\mcc_codes.json"

with open(json_path, encoding='utf-8') as f:
    data = json.load(f)

# Inspect the data type and keys
print(type(data))
if isinstance(data, dict):
    print(list(data.keys())[:5])  # Showing first 5 keys to keep output clean

# Convert dictionary into a DataFrame
df2 = pd.DataFrame(
    list(data.items()),
    columns=['Code', 'Industry']
)

df2.head()
# Out:
# <class 'dict'>
# ['5812', '5541', '7996', '5411', '4784']
#    Code                              Industry
# 0  5812         Eating Places and Restaurants
# 1  5541                      Service Stations
# 2  7996  Amusement Parks, Carnivals, Circuses
# 3  5411          Grocery Stores, Supermarkets
# 4  4784                 Tolls and Bridge Fees

# %%
df.tail()
# Out:
#                 id                 date  client_id  card_id  amount  \
# 13305910  23761868  2019-10-31 23:56:00       1718     2379   $1.11
# 13305911  23761869  2019-10-31 23:56:00       1766     2066  $12.80
# 13305912  23761870  2019-10-31 23:57:00        199     1031  $40.44
# 13305913  23761873  2019-10-31 23:58:00       1986     5443   $4.00
# 13305914  23761874  2019-10-31 23:59:00        489     5697  $12.88
#
#                     use_chip  merchant_id merchant_city merchant_state  \
# 13305910    Chip Transaction        86438   West Covina             CA
# 13305911  Online Transaction        39261        ONLINE            NaN
# 13305912   Swipe Transaction         2925         Allen             TX
# 13305913    Chip Transaction        46284     Daly City             CA
# 13305914    Chip Transaction        24658    Greenbrier             TN
#
#               zip   mcc errors
# 13305910  91792.0  5499    NaN
# 13305911      NaN  5815    NaN
# 13305912  75002.0  4900    NaN
# 13305913  94014.0  5411    NaN
# 13305914  37073.0  5921    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13305915 entries, 0 to 13305914
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              int64
#  1   date            object
#  2   client_id       int64
#  3   card_id         int64
#  4   amount          object
#  5   use_chip        object
#  6   merchant_id     int64
#  7   merchant_city   object
#  8   merchant_state  object
#  9   zip             float64
#  10  mcc             int64
#  11  errors          object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.2+ GB

# %%
df.isna().sum()
# Out:
# id                       0
# date                     0
# client_id                0
# card_id                  0
# amount                   0
# use_chip                 0
# merchant_id              0
# merchant_city            0
# merchant_state     1563700
# zip                1652706
# mcc                      0
# errors            13094522
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])
df['amount'] = (
    df['amount']
    .str.replace('[\$,]', '', regex=True)
)

df['amount'] = pd.to_numeric(df['amount'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13305915 entries, 0 to 13305914
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              int64
#  1   date            datetime64[ns]
#  2   client_id       int64
#  3   card_id         int64
#  4   amount          float64
#  5   use_chip        object
#  6   merchant_id     int64
#  7   merchant_city   object
#  8   merchant_state  object
#  9   zip             float64
#  10  mcc             int64
#  11  errors          object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(4)
# memory usage: 1.2+ GB

# %%
df['mcc'] = df['mcc'].astype(int)
df2['Code'] = df2['Code'].astype(int)

df['Stores'] = df['mcc'].map(df2.set_index('Code')['Industry'])

df
# Out:
#                 id                date  client_id  card_id  amount  \
# 0          7475327 2010-01-01 00:01:00       1556     2972  -77.00
# 1          7475328 2010-01-01 00:02:00        561     4575   14.57
# 2          7475329 2010-01-01 00:02:00       1129      102   80.00
# 3          7475331 2010-01-01 00:05:00        430     2860  200.00
# 4          7475332 2010-01-01 00:06:00        848     3915   46.41
# ...            ...                 ...        ...      ...     ...
# 13305910  23761868 2019-10-31 23:56:00       1718     2379    1.11
# 13305911  23761869 2019-10-31 23:56:00       1766     2066   12.80
# 13305912  23761870 2019-10-31 23:57:00        199     1031   40.44
# 13305913  23761873 2019-10-31 23:58:00       1986     5443    4.00
# 13305914  23761874 2019-10-31 23:59:00        489     5697   12.88
#
#                     use_chip  merchant_id merchant_city merchant_state  \
# 0          Swipe Transaction        59935        Beulah             ND
# 1          Swipe Transaction        67570    Bettendorf             IA
# 2          Swipe Transaction        27092         Vista             CA
# 3          Swipe Transaction        27092   Crown Point             IN
# 4          Swipe Transaction        13051       Harwood             MD
# ...                      ...          ...           ...            ...
# 13305910    Chip Transaction        86438   West Covina             CA
# 13305911  Online Transaction        39261        ONLINE            NaN
# 13305912   Swipe Transaction         2925         Allen             TX
# 13305913    Chip Transaction        46284     Daly City             CA
# 13305914    Chip Transaction        24658    Greenbrier             TN
#
#               zip   mcc errors                                      Stores
# 0         58523.0  5499    NaN                   Miscellaneous Food Stores
# 1         52722.0  5311    NaN                           Department Stores
# 2         92084.0  4829    NaN                              Money Transfer
# 3         46307.0  4829    NaN                              Money Transfer
# 4         20776.0  5813    NaN       Drinking Places (Alcoholic Beverages)
# ...           ...   ...    ...                                         ...
# 13305910  91792.0  5499    NaN                   Miscellaneous Food Stores
# 13305911      NaN  5815    NaN          Digital Goods - Media, Books, Apps
# 13305912  75002.0  4900    NaN  Utilities - Electric, Gas, Water, Sanitary
# 13305913  94014.0  5411    NaN                Grocery Stores, Supermarkets
# 13305914  37073.0  5921    NaN          Package Stores, Beer, Wine, Liquor
#
# [13305915 rows x 13 columns]

# %%
df[df['merchant_state'].isna()]
# Out:
#                 id                date  client_id  card_id  amount  \
# 7          7475335 2010-01-01 00:14:00       1684     2140   26.46
# 8          7475336 2010-01-01 00:21:00        335     5131  261.58
# 18         7475346 2010-01-01 00:34:00        394     4717   26.04
# 24         7475353 2010-01-01 00:43:00        301     3742   10.17
# 26         7475356 2010-01-01 00:45:00        566     3439   16.86
# ...            ...                 ...        ...      ...     ...
# 13305879  23761832 2019-10-31 23:22:00       1556     2972   17.65
# 13305880  23761833 2019-10-31 23:22:00       1797     5660   34.81
# 13305888  23761843 2019-10-31 23:33:00       1069     5167   59.71
# 13305897  23761853 2019-10-31 23:39:00       1422     5696  694.30
# 13305911  23761869 2019-10-31 23:56:00       1766     2066   12.80
#
#                     use_chip  merchant_id merchant_city merchant_state  zip  \
# 7         Online Transaction        39021        ONLINE            NaN  NaN
# 8         Online Transaction        50292        ONLINE            NaN  NaN
# 18        Online Transaction        39021        ONLINE            NaN  NaN
# 24        Online Transaction        39021        ONLINE            NaN  NaN
# 26        Online Transaction        16798        ONLINE            NaN  NaN
# ...                      ...          ...           ...            ...  ...
# 13305879  Online Transaction        88459        ONLINE            NaN  NaN
# 13305880  Online Transaction        15143        ONLINE            NaN  NaN
# 13305888  Online Transaction        39021        ONLINE            NaN  NaN
# 13305897  Online Transaction        70268        ONLINE            NaN  NaN
# 13305911  Online Transaction        39261        ONLINE            NaN  NaN
#
#            mcc errors                              Stores
# 7         4784    NaN               Tolls and Bridge Fees
# 8         7801    NaN  Athletic Fields, Commercial Sports
# 18        4784    NaN               Tolls and Bridge Fees
# 24        4784    NaN               Tolls and Bridge Fees
# 26        4121    NaN             Taxicabs and Limousines
# ...        ...    ...                                 ...
# 13305879  5311    NaN                   Department Stores
# 13305880  4784    NaN               Tolls and Bridge Fees
# 13305888  4784    NaN               Tolls and Bridge Fees
# 13305897  4722    NaN                     Travel Agencies
# 13305911  5815    NaN  Digital Goods - Media, Books, Apps
#
# [1563700 rows x 13 columns]

# %%
df['merchant_state'].fillna('Online', inplace=True)
df['zip'].fillna('Online', inplace=True)

# %%
df.isna().sum()
# Out:
# id                       0
# date                     0
# client_id                0
# card_id                  0
# amount                   0
# use_chip                 0
# merchant_id              0
# merchant_city            0
# merchant_state           0
# zip                      0
# mcc                      0
# errors            13094522
# Stores                   0
# dtype: int64

# %%
df['errors'].fillna('Successfull Purchase', inplace=True)

# %%
df.isna().sum()
# Out:
# id                0
# date              0
# client_id         0
# card_id           0
# amount            0
# use_chip          0
# merchant_id       0
# merchant_city     0
# merchant_state    0
# zip               0
# mcc               0
# errors            0
# Stores            0
# dtype: int64

# %%
df
# Out:
#                 id                date  client_id  card_id  amount  \
# 0          7475327 2010-01-01 00:01:00       1556     2972  -77.00
# 1          7475328 2010-01-01 00:02:00        561     4575   14.57
# 2          7475329 2010-01-01 00:02:00       1129      102   80.00
# 3          7475331 2010-01-01 00:05:00        430     2860  200.00
# 4          7475332 2010-01-01 00:06:00        848     3915   46.41
# ...            ...                 ...        ...      ...     ...
# 13305910  23761868 2019-10-31 23:56:00       1718     2379    1.11
# 13305911  23761869 2019-10-31 23:56:00       1766     2066   12.80
# 13305912  23761870 2019-10-31 23:57:00        199     1031   40.44
# 13305913  23761873 2019-10-31 23:58:00       1986     5443    4.00
# 13305914  23761874 2019-10-31 23:59:00        489     5697   12.88
#
#                     use_chip  merchant_id merchant_city merchant_state  \
# 0          Swipe Transaction        59935        Beulah             ND
# 1          Swipe Transaction        67570    Bettendorf             IA
# 2          Swipe Transaction        27092         Vista             CA
# 3          Swipe Transaction        27092   Crown Point             IN
# 4          Swipe Transaction        13051       Harwood             MD
# ...                      ...          ...           ...            ...
# 13305910    Chip Transaction        86438   West Covina             CA
# 13305911  Online Transaction        39261        ONLINE         Online
# 13305912   Swipe Transaction         2925         Allen             TX
# 13305913    Chip Transaction        46284     Daly City             CA
# 13305914    Chip Transaction        24658    Greenbrier             TN
#
#               zip   mcc                errors  \
# 0         58523.0  5499  Successfull Purchase
# 1         52722.0  5311  Successfull Purchase
# 2         92084.0  4829  Successfull Purchase
# 3         46307.0  4829  Successfull Purchase
# 4         20776.0  5813  Successfull Purchase
# ...           ...   ...                   ...
# 13305910  91792.0  5499  Successfull Purchase
# 13305911   Online  5815  Successfull Purchase
# 13305912  75002.0  4900  Successfull Purchase
# 13305913  94014.0  5411  Successfull Purchase
# 13305914  37073.0  5921  Successfull Purchase
#
#                                               Stores
# 0                          Miscellaneous Food Stores
# 1                                  Department Stores
# 2                                     Money Transfer
# 3                                     Money Transfer
# 4              Drinking Places (Alcoholic Beverages)
# ...                                              ...
# 13305910                   Miscellaneous Food Stores
# 13305911          Digital Goods - Media, Books, Apps
# 13305912  Utilities - Electric, Gas, Water, Sanitary
# 13305913                Grocery Stores, Supermarkets
# 13305914          Package Stores, Beer, Wine, Liquor
#
# [13305915 rows x 13 columns]

# %%
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
from IPython.display import IFrame

plt.figure(figsize=(14,8))
topStores = (
    df.groupby('Stores')['amount']
   .sum()
      .reset_index()
      .sort_values(by='amount', ascending=False).head(10)
)

topStores
sns.barplot(
    y='amount',
    x='Stores',
    data=topStores,
    palette='tab20' 
)

plt.title('Top 10 Stores by Sales', fontsize=18)
plt.ylabel('Sales')
plt.xlabel('Store')
plt.xticks(rotation=45)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.countplot(data=df, x='use_chip', palette='viridis')

plt.title('Most Used Transactions Method', fontsize=16)
plt.xlabel('Transactions Method')
plt.ylabel('Number of Transactions')
plt.show()

# %%
error_counts = df['errors'].value_counts()

plt.figure(figsize=(12, 10))

sns.barplot(
    x=error_counts.values, 
    y=error_counts.index, 
    palette='Set2'
)

plt.title('Transaction Outcomes & Errors Count', fontsize=18)
plt.xlabel('Number of Occurrences', fontsize=14)
plt.ylabel('Outcome Type', fontsize=14)
plt.grid(alpha=0.6)
for i, v in enumerate(error_counts.values):
    plt.text(v + 3, i, str(v), color='black', va='center', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
yearly_counts = df['date'].dt.year.value_counts().sort_index()

plt.figure(figsize=(12, 6))

sns.lineplot(
    x=yearly_counts.index, 
    y=yearly_counts.values, 
    marker='o',       
    markersize=10, 
    linewidth=3, 
    palette='tab20'
)

plt.title('Total Transactions per Year', fontsize=18, pad=15)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Transactions', fontsize=14)

plt.xticks(yearly_counts.index) 

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %%
state_amounts = df.groupby('merchant_state')['amount'].sum().nlargest(10)

plt.figure(figsize=(12, 8))

sns.barplot(
    x=state_amounts.values, 
    y=state_amounts.index, 
    palette='viridis'
)

plt.title('Top 10 States by Total Transaction Amount', fontsize=18)
plt.xlabel('Total Amount ($)', fontsize=14)
plt.ylabel('State', fontsize=14)
from matplotlib.ticker import StrMethodFormatter
plt.gca().xaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))

plt.grid(axis='x', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
state_amounts = df.groupby('merchant_city')['amount'].sum().nlargest(10)

plt.figure(figsize=(12, 8))

sns.barplot(
    x=state_amounts.values, 
    y=state_amounts.index, 
    palette='Set3'
)

plt.title('Top 10 Cities by Total Transaction Amount', fontsize=18)
plt.xlabel('Total Amount ($)', fontsize=14)
plt.ylabel('City', fontsize=14)
from matplotlib.ticker import StrMethodFormatter
plt.gca().xaxis.set_major_formatter(StrMethodFormatter('${x:,.0f}'))

plt.grid(axis='x', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Cards Data Analysis

# %%
df3 = pd.read_csv(r"C:\Users\DELL\Desktop\Skills\Financial Analysis\cards_data.csv")
df3
# Out:
#         id  client_id  card_brand        card_type       card_number  expires  \
# 0     4524        825        Visa            Debit  4344676511950444  12/2022
# 1     2731        825        Visa            Debit  4956965974959986  12/2020
# 2     3701        825        Visa            Debit  4582313478255491  02/2024
# 3       42        825        Visa           Credit  4879494103069057  08/2024
# 4     4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
# ...    ...        ...         ...              ...               ...      ...
# 6141  5361        185        Amex           Credit   300609782832003  01/2024
# 6142  2711        185        Visa           Credit  4718517475996018  01/2021
# 6143  1305       1007  Mastercard           Credit  5929512204765914  08/2020
# 6144   743       1110  Mastercard            Debit  5589768928167462  01/2020
# 6145  3199       1110        Visa           Credit  4994011318343994  12/2020
#
#       cvv has_chip  num_cards_issued credit_limit acct_open_date  \
# 0     623      YES                 2       $24295        09/2002
# 1     393      YES                 2       $21968        04/2014
# 2     719      YES                 2       $46414        07/2003
# 3     693       NO                 1       $12400        01/2003
# 4      75      YES                 1          $28        09/2008
# ...   ...      ...               ...          ...            ...
# 6141  663      YES                 1        $6900        11/2000
# 6142  492      YES                 2        $5700        04/2012
# 6143  237       NO                 2        $9200        02/2012
# 6144  630      YES                 1       $28074        01/2020
# 6145  120      YES                 1       $14400        05/2017
#
#       year_pin_last_changed card_on_dark_web
# 0                      2008               No
# 1                      2014               No
# 2                      2004               No
# 3                      2012               No
# 4                      2009               No
# ...                     ...              ...
# 6141                   2013               No
# 6142                   2012               No
# 6143                   2012               No
# 6144                   2020               No
# 6145                   2017               No
#
# [6146 rows x 13 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6146 entries, 0 to 6145
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     6146 non-null   int64
#  1   client_id              6146 non-null   int64
#  2   card_brand             6146 non-null   object
#  3   card_type              6146 non-null   object
#  4   card_number            6146 non-null   int64
#  5   expires                6146 non-null   object
#  6   cvv                    6146 non-null   int64
#  7   has_chip               6146 non-null   object
#  8   num_cards_issued       6146 non-null   int64
#  9   credit_limit           6146 non-null   object
#  10  acct_open_date         6146 non-null   object
#  11  year_pin_last_changed  6146 non-null   int64
#  12  card_on_dark_web       6146 non-null   object
# dtypes: int64(6), object(7)
# memory usage: 624.3+ KB

# %%
df3['expires']=pd.to_datetime(df3['expires'], errors='coerce')
df3['acct_open_date']=pd.to_datetime(df3['acct_open_date'], errors='coerce')
df3['credit_limit'] = (
 df3['credit_limit']
    .str.replace('[\$,]', '', regex=True)
)

df3['credit_limit'] = pd.to_numeric(df3['credit_limit'], errors='coerce')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6146 entries, 0 to 6145
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     6146 non-null   int64
#  1   client_id              6146 non-null   int64
#  2   card_brand             6146 non-null   object
#  3   card_type              6146 non-null   object
#  4   card_number            6146 non-null   int64
#  5   expires                6146 non-null   datetime64[ns]
#  6   cvv                    6146 non-null   int64
#  7   has_chip               6146 non-null   object
#  8   num_cards_issued       6146 non-null   int64
#  9   credit_limit           6146 non-null   int64
#  10  acct_open_date         6146 non-null   datetime64[ns]
#  11  year_pin_last_changed  6146 non-null   int64
#  12  card_on_dark_web       6146 non-null   object
# dtypes: datetime64[ns](2), int64(7), object(4)
# memory usage: 624.3+ KB

# %%
df3.head()
# Out:
#      id  client_id  card_brand        card_type       card_number    expires  \
# 0  4524        825        Visa            Debit  4344676511950444 2022-12-01
# 1  2731        825        Visa            Debit  4956965974959986 2020-12-01
# 2  3701        825        Visa            Debit  4582313478255491 2024-02-01
# 3    42        825        Visa           Credit  4879494103069057 2024-08-01
# 4  4659        825  Mastercard  Debit (Prepaid)  5722874738736011 2009-03-01
#
#    cvv has_chip  num_cards_issued  credit_limit acct_open_date  \
# 0  623      YES                 2         24295     2002-09-01
# 1  393      YES                 2         21968     2014-04-01
# 2  719      YES                 2         46414     2003-07-01
# 3  693       NO                 1         12400     2003-01-01
# 4   75      YES                 1            28     2008-09-01
#
#    year_pin_last_changed card_on_dark_web
# 0                   2008               No
# 1                   2014               No
# 2                   2004               No
# 3                   2012               No
# 4                   2009               No

# %%
df3.tail()
# Out:
#         id  client_id  card_brand card_type       card_number    expires  cvv  \
# 6141  5361        185        Amex    Credit   300609782832003 2024-01-01  663
# 6142  2711        185        Visa    Credit  4718517475996018 2021-01-01  492
# 6143  1305       1007  Mastercard    Credit  5929512204765914 2020-08-01  237
# 6144   743       1110  Mastercard     Debit  5589768928167462 2020-01-01  630
# 6145  3199       1110        Visa    Credit  4994011318343994 2020-12-01  120
#
#      has_chip  num_cards_issued  credit_limit acct_open_date  \
# 6141      YES                 1          6900     2000-11-01
# 6142      YES                 2          5700     2012-04-01
# 6143       NO                 2          9200     2012-02-01
# 6144      YES                 1         28074     2020-01-01
# 6145      YES                 1         14400     2017-05-01
#
#       year_pin_last_changed card_on_dark_web
# 6141                   2013               No
# 6142                   2012               No
# 6143                   2012               No
# 6144                   2020               No
# 6145                   2017               No

# %%
df3.describe().T
# Out:
#                         count                           mean  \
# id                     6146.0                         3072.5
# client_id              6146.0                     994.939636
# card_number            6146.0             4820425803848956.0
# expires                  6146  2020-10-08 06:30:06.443215360
# cvv                    6146.0                     506.220794
# num_cards_issued       6146.0                       1.503091
# credit_limit           6146.0                    14347.49398
# acct_open_date           6146  2011-01-15 12:55:31.727953152
# year_pin_last_changed  6146.0                    2013.436707
#
#                                        min                  25%  \
# id                                     0.0              1536.25
# client_id                              0.0               492.25
# card_number              300105541992311.0   4486365176018953.0
# expires                1997-07-01 00:00:00  2020-02-01 00:00:00
# cvv                                    0.0                257.0
# num_cards_issued                       1.0                  1.0
# credit_limit                           0.0              7042.75
# acct_open_date         1991-01-01 00:00:00  2006-10-01 00:00:00
# year_pin_last_changed               2002.0               2010.0
#
#                                        50%                  75%  \
# id                                  3072.5              4608.75
# client_id                            992.0               1495.0
# card_number             5108957434464472.0   5585237469514469.0
# expires                2021-09-01 00:00:00  2023-05-01 00:00:00
# cvv                                  516.5                756.0
# num_cards_issued                       1.0                  2.0
# credit_limit                       12592.5              19156.5
# acct_open_date         2010-02-15 00:00:00  2016-05-01 00:00:00
# year_pin_last_changed               2013.0               2017.0
#
#                                        max                  std
# id                                  6145.0          1774.341709
# client_id                           1999.0           578.614626
# card_number             6997197066610978.0  1328582205754834.25
# expires                2024-12-01 00:00:00                  NaN
# cvv                                  999.0           289.431123
# num_cards_issued                       3.0             0.519191
# credit_limit                      151223.0         12014.463884
# acct_open_date         2020-02-01 00:00:00                  NaN
# year_pin_last_changed               2020.0             4.270699

# %%
df3.isna().sum()
# Out:
# id                       0
# client_id                0
# card_brand               0
# card_type                0
# card_number              0
# expires                  0
# cvv                      0
# has_chip                 0
# num_cards_issued         0
# credit_limit             0
# acct_open_date           0
# year_pin_last_changed    0
# card_on_dark_web         0
# dtype: int64

# %%
df3.columns
# Out:
# Index(['id', 'client_id', 'card_brand', 'card_type', 'card_number', 'expires',
#        'cvv', 'has_chip', 'num_cards_issued', 'credit_limit', 'acct_open_date',
#        'year_pin_last_changed', 'card_on_dark_web'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df3, x='card_brand', palette='viridis')
plt.title('Distribution of Card Brands', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8, 8))
type_counts = df3['card_type'].value_counts()
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Card Type Breakdown', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df3['credit_limit'], kde=True, color='skyblue', bins=30)
plt.title('Distribution of Credit Limits', fontsize=15)
plt.xlabel('Credit Limit ($)')
plt.show()

# %%
numeric_cols = df3.select_dtypes(include=['number', 'bool'])

corr_matrix = numeric_cols.corr()

plt.figure(figsize=(12, 10))


sns.heatmap(
    corr_matrix, 
    annot=True,         
    fmt=".2f",         
    cmap='coolwarm',     
    center=0,           
    linewidths=0.5,
    square=True         
)

plt.title('Correlation Heatmap of All Numeric Variables', fontsize=16, pad=20)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df3['year_pin_last_changed'], bins=15, color='skyblue')
plt.title('Recency of PIN Changes (Year)', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12, 6))
df3['acct_open_date'] = pd.to_datetime(df3['acct_open_date'])
yearly_openings = df3['acct_open_date'].dt.year.value_counts().sort_index()
sns.lineplot(x=yearly_openings.index, y=yearly_openings.values, marker='o', color='green')
plt.title('Accounts Opened Over the Years', fontsize=15)
plt.xlabel('Year')
plt.ylabel('Number Of Accounts')
plt.grid(alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df3, x='card_brand', y='credit_limit', palette='Set2')
plt.title('Credit Limit Ranges by Brand', fontsize=15)
plt.show()

# %% [markdown]
# # Users Data Analysis

# %%
df4 = pd.read_csv(r"C:\Users\DELL\Desktop\Skills\Financial Analysis\users_data.csv")
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2000 non-null   int64
#  1   current_age        2000 non-null   int64
#  2   retirement_age     2000 non-null   int64
#  3   birth_year         2000 non-null   int64
#  4   birth_month        2000 non-null   int64
#  5   gender             2000 non-null   object
#  6   address            2000 non-null   object
#  7   latitude           2000 non-null   float64
#  8   longitude          2000 non-null   float64
#  9   per_capita_income  2000 non-null   object
#  10  yearly_income      2000 non-null   object
#  11  total_debt         2000 non-null   object
#  12  credit_score       2000 non-null   int64
#  13  num_credit_cards   2000 non-null   int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 218.9+ KB

# %%
df4.head()
# Out:
#      id  current_age  retirement_age  birth_year  birth_month  gender  \
# 0   825           53              66        1966           11  Female
# 1  1746           53              68        1966           12  Female
# 2  1718           81              67        1938           11  Female
# 3   708           63              63        1957            1  Female
# 4  1164           43              70        1976            9    Male
#
#                     address  latitude  longitude per_capita_income  \
# 0             462 Rose Lane     34.15    -117.76            $29278
# 1    3606 Federal Boulevard     40.76     -73.74            $37891
# 2           766 Third Drive     34.02    -117.89            $22681
# 3          3 Madison Street     40.71     -73.99           $163145
# 4  9620 Valley Stream Drive     37.76    -122.44            $53797
#
#   yearly_income total_debt  credit_score  num_credit_cards
# 0        $59696    $127613           787                 5
# 1        $77254    $191349           701                 5
# 2        $33483       $196           698                 5
# 3       $249925    $202328           722                 4
# 4       $109687    $183855           675                 1

# %%
df4.tail()
# Out:
#         id  current_age  retirement_age  birth_year  birth_month  gender  \
# 1995   986           32              70        1987            7    Male
# 1996  1944           62              65        1957           11  Female
# 1997   185           47              67        1973            1  Female
# 1998  1007           66              60        1954            2    Male
# 1999  1110           21              60        1998           11  Female
#
#                     address  latitude  longitude per_capita_income  \
# 1995    6577 Lexington Lane     40.65     -73.58            $23550
# 1996            2 Elm Drive     38.95     -84.54            $24218
# 1997    276 Fifth Boulevard     40.66     -74.19            $15175
# 1998   259 Valley Boulevard     40.24     -76.92            $25336
# 1999  472 Ocean View Street     42.86     -71.48            $32325
#
#      yearly_income total_debt  credit_score  num_credit_cards
# 1995        $48010     $87837           703                 3
# 1996        $49378    $104480           740                 4
# 1997        $30942     $71066           779                 3
# 1998        $54654     $27241           618                 1
# 1999        $65909    $181261           673                 2

# %%
cols_to_fix = ['per_capita_income', 'yearly_income', 'total_debt']

for col in cols_to_fix:
   
    df4[col] = df4[col].astype(str).str.replace('[\$,]', '', regex=True)
    
  
    df4[col] = pd.to_numeric(df4[col], errors='coerce')

df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2000 non-null   int64
#  1   current_age        2000 non-null   int64
#  2   retirement_age     2000 non-null   int64
#  3   birth_year         2000 non-null   int64
#  4   birth_month        2000 non-null   int64
#  5   gender             2000 non-null   object
#  6   address            2000 non-null   object
#  7   latitude           2000 non-null   float64
#  8   longitude          2000 non-null   float64
#  9   per_capita_income  2000 non-null   int64
#  10  yearly_income      2000 non-null   int64
#  11  total_debt         2000 non-null   int64
#  12  credit_score       2000 non-null   int64
#  13  num_credit_cards   2000 non-null   int64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 218.9+ KB

# %%
df4.isna().sum()
# Out:
# id                   0
# current_age          0
# retirement_age       0
# birth_year           0
# birth_month          0
# gender               0
# address              0
# latitude             0
# longitude            0
# per_capita_income    0
# yearly_income        0
# total_debt           0
# credit_score         0
# num_credit_cards     0
# dtype: int64

# %%
df4.columns
# Out:
# Index(['id', 'current_age', 'retirement_age', 'birth_year', 'birth_month',
#        'gender', 'address', 'latitude', 'longitude', 'per_capita_income',
#        'yearly_income', 'total_debt', 'credit_score', 'num_credit_cards'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df4['current_age'], bins=20, kde=True, color='royalblue')
plt.title('Distribution of Client Ages', fontsize=15)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df4['yearly_income'], bins=30, kde=True, color='forestgreen')
plt.title('Distribution of Yearly Income', fontsize=15)
plt.xlabel('Yearly Income ($)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df4, x='num_credit_cards', palette='mako')
plt.title('Number of Credit Cards Owned', fontsize=15)
plt.xlabel('Number of Cards')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df4['retirement_age'], bins=15, color='purple')
plt.title('Planned Retirement Age', fontsize=15)
plt.xlabel('Age')
plt.show()

# %% [markdown]
# # Conclusion
# Transaction Data Insights
# The most common transaction method is the swipe, followed by chip and online payments. Overall, the system is highly reliable, with 90% of purchases being successful. Among the failed transactions, 3% are due to insufficient balance, while the remaining 7% are due to various errors, such as bad PINs and technical glitches. Historically, sales grew steadily from 2010 to 2018 but saw a sudden drop in 2019. Currently, most customers prefer paying online, with California, Texas, and New York leading as the top states by sales volume.
#
# Credit Card Patterns
# Mastercard is the most frequently used brand, followed by Visa and Amex, with Discover in last place. Interestingly, Debit cards are the most popular card type, representing 57% of usage. Credit limit data shows a right-skewed distribution, meaning it is not normally distributed and is concentrated at certain levels. Notably, 2020 saw a significant spike in both PIN changes and new account openings compared to all previous years.
#
# User & Demographic Summary
# Financial Health: By comparing Yearly Income and Total Debt, you can clearly identify "high-risk" versus "high-value" segments.
# Demographics: Analysis of Current Age and Retirement Age helps predict future spending or saving patterns.
# Creditworthiness: The Credit Score and Number of Credit Cards show how heavily  clients rely on credit and their overall financial stability.
